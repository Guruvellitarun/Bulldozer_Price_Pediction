# %% [markdown]
# <a href="https://colab.research.google.com/github/Guruvellitarun/Bulldozer_Price_Pediction/blob/main/Name_llm_tunning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unsloth trl peft accelerate bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.9/511.9 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.0/130.0 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.6/213.6 kB 18.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
import pandas as pd
import json
import re

# %%
# # importing the csv file
# data = pd.read_excel('drive/MyDrive/Training_dataset.xlsx')
# data.head()

# %%
# data.drop(['Exchange:Ticker', 'Company Type', 'Company Status',
#            'Geographic Locations', 'Security Tickers']
#           , axis=1, inplace=True)

# %%
# data.columns

# %%
# data.head()

# %%
# data.describe()

# %%
# count = (data['Business Description'].str.strip() == '-').sum()
# print("Rows with only '-' :", count)

# %%
# rows_with_only_dash = data[data['Business Description'].str.strip() == '-']
# print(rows_with_only_dash)

# %%
# data = data[data['Business Description'].str.strip() != '-']

# %%
# data.describe()

# %%
# import re

# def clean_company_name(name):
#     name = re.sub(r"\s*\(.*?\)", "", name)

#     name = re.sub(r"\b(Inc\.?|Corporation|Corp\.?|Ltd\.?|LLC|PLC)\b", "", name, flags=re.IGNORECASE)

#     name = re.sub(r"[.,]+$", "", name)

#     name = re.sub(r"\s+", " ", name).strip()

#     return name

# %%
# # Apply to Company Name column
# data['Company Name'] = data['Company Name'].apply(clean_company_name)

# %%
# import re

# suffixes = ["Inc", "Inc.", "LLC", "LLC.", "Ltd", "Ltd.", "Corporation", "Corp", "Corp."]

# def clean_description(row):
#     desc = str(row["Business Description"]).strip()
#     company = str(row["Company Name"]).strip()

#     # Pattern: Company name + optional comma + optional suffix
#     pattern = rf"^{re.escape(company)}(?:,?\s+(?:{'|'.join(suffixes)}))?\s*"

#     # Remove from start
#     desc = re.sub(pattern, "", desc, flags=re.IGNORECASE).strip(",. ").strip()

#     return desc

# # Apply safely
# data.loc[:, "Business Description"] = data.apply(clean_description, axis=1)

# %%
# data.head()

# %%
# # Our data is ready now we are going to convert this data into Jsonl format

# subset = data.head(1000)

# records = [
#     {"input": row["Business Description"], "output": row["Company Name"]}
#     for _, row in subset.iterrows()
# ]

# with open("companies_1000.json", "w") as f:
#     json.dump(records, f, indent=4)

# print("✅ Saved first 1000 rows to companies_1000.json")

# %%
#import new dataset which is india companys
df = pd.read_csv("drive/MyDrive/Indian_Companies.csv")
# Out:
# /tmp/ipython-input-2778738948.py:2: DtypeWarning: Columns (3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("drive/MyDrive/Indian_Companies.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        name  rating reviews   domain           location  \
# 0           0         TCS     3.9   16.1k   Public  Mumbai + 156 more
# 1           1   Accenture     4.0   14.1k  Private   Dublin + 87 more
# 2           2  ICICI Bank     4.1   12.7k   Public  Mumbai + 724 more
# 3           3   Cognizant     3.9   12.1k  Private  Teaneck + 44 more
# 4           4   HDFC Bank     4.0   10.9k   Public  Mumbai + 692 more
#
#       years_old employee_strength  \
# 0  52 years old  10000+ employees
# 1  31 years old  10000+ employees
# 2  26 years old  10000+ employees
# 3  26 years old  10000+ employees
# 4  26 years old  10000+ employees
#
#                                                 tags  \
# 0               Consulting, IT/ITES, MNC, Fortune500
# 1                           Consulting, IT/ITES, MNC
# 2  Banking/Insurance/Accounting, Financial Servic...
# 3                                       IT/ITES, MNC
# 4  Banking/Insurance/Accounting, Financial Servic...
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# name                      0
# rating                56501
# reviews                   0
# domain               380701
# location             136124
# years_old            444812
# employee_strength    405953
# tags                 315674
# about                436950
# dtype: int64

# %%
len(df)
# Out:
# 452520

# %%
452521 - 436950
# Out:
# 15571

# %%
df_cleaned = df.dropna(subset=['about'])

# %%
df_cleaned.isna().sum()
# Out:
# Unnamed: 0              0
# name                    0
# rating                790
# reviews                 0
# domain               2808
# location              236
# years_old            8063
# employee_strength    1949
# tags                 1794
# about                   0
# dtype: int64

# %%
df_cleaned.drop(['Unnamed: 0', 'rating', 'reviews', 'domain', 'location', 'years_old', 'employee_strength', 'tags'], axis = 1, inplace = True)
# Out:
# /tmp/ipython-input-1035853946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop(['Unnamed: 0', 'rating', 'reviews', 'domain', 'location', 'years_old', 'employee_strength', 'tags'], axis = 1, inplace = True)

# %%
df_cleaned.head()
# Out:
#          name                                              about
# 0         TCS  Tata Consultancy Services is an IT services, c...
# 1   Accenture  Accenture is a leading global professional ser...
# 2  ICICI Bank  ICICI Bank is India's largest private sector b...
# 3   Cognizant  Cognizant (NASDAQ-100: CTSH) is one of the wor...
# 4   HDFC Bank  HDFC Bank is one of India’s leading private ba...

# %%
SUFFIXES = r"(limited|ltd|inc|llc|plc|corp(?:oration)?|company|co|group)"

def build_aliases(name: str, text: str):
    aliases = set()
    nm = (name or "").strip()
    if not nm:
      return aliases

    aliases.add(nm)

    # variant without corporate suffixes (for alias building only)
    nm_no_suf = re.sub(rf"\b{SUFFIXES}\b\.?", "", nm, flags=re.IGNORECASE).strip()
    if nm_no_suf and nm_no_suf.lower() != nm.lower():
        aliases.add(nm_no_suf)

    # acronym from first letters (e.g., Tata Consultancy Services -> TCS)
    words = re.findall(r"[A-Za-z0-9]+", nm_no_suf or nm)
    if len(words) >= 2:
        ac = "".join(w[0] for w in words).upper()
        if len(ac) >= 2:
            aliases.add(ac)

    # pull uppercase abbreviations/tickers from parentheses in the original text
    for par in re.findall(r"\(([^)]{1,40})\)", text or ""):
        for tok in re.findall(r"[A-Z]{2,6}", par):
            aliases.add(tok)

    return sorted(aliases, key=len, reverse=True)  # longer first

def clean_description(row):
    text = str(row.get("about", "") or "")
    name = str(row.get("name", "") or "")

    # 1) Remove URLs early
    text = re.sub(r"http\S+|www\.\S+", " ", text, flags=re.IGNORECASE)

    # 2) Build aliases BEFORE dropping parentheses so we can capture (TCS), (NASDAQ: CTSH), etc.
    aliases = build_aliases(name, text)

    # 3) Drop parenthetical blobs like (TCS), (NASDAQ: CTSH)
    text = re.sub(r"\([^)]*\)", " ", text)

    # 4) Remove exchange/ticker phrases that may appear outside parentheses
    text = re.sub(r"\b(NASDAQ|NYSE|BSE|NSE)\b[:\s]*[A-Z0-9.\-]{1,8}", " ", text, flags=re.IGNORECASE)

    # 5) Remove company name & aliases anywhere (with optional possessive ’s/'s)
    if aliases:
        pattern = r"(?<!\w)(?:" + "|".join(map(re.escape, aliases)) + r")(?:'s|’s)?(?!\w)"
        text = re.sub(pattern, " ", text, flags=re.IGNORECASE)

    # 6) Whitespace/punctuation tidy
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"^\W+|\W+$", "", text)
    return text.strip()

# %%
# Apply cleaning
df_cleaned["clean_about"] = df_cleaned.apply(clean_description, axis=1)
# Out:
# /tmp/ipython-input-699567284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["clean_about"] = df_cleaned.apply(clean_description, axis=1)

# %%
df_cleaned.head()
# Out:
#          name                                              about  \
# 0         TCS  Tata Consultancy Services is an IT services, c...
# 1   Accenture  Accenture is a leading global professional ser...
# 2  ICICI Bank  ICICI Bank is India's largest private sector b...
# 3   Cognizant  Cognizant (NASDAQ-100: CTSH) is one of the wor...
# 4   HDFC Bank  HDFC Bank is one of India’s leading private ba...
#
#                                          clean_about
# 0  Tata Consultancy Services is an IT services, c...
# 1  is a leading global professional services comp...
# 2  is India's largest private sector bank with to...
# 3  is one of the world’s leading professional ser...
# 4  is one of India’s leading private banks and wa...

# %%
df_cleaned.drop('about', axis = 1, inplace=True)
# Out:
# /tmp/ipython-input-1194023482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop('about', axis = 1, inplace=True)

# %%
df_cleaned.head()
# Out:
#          name                                        clean_about
# 0         TCS  Tata Consultancy Services is an IT services, c...
# 1   Accenture  is a leading global professional services comp...
# 2  ICICI Bank  is India's largest private sector bank with to...
# 3   Cognizant  is one of the world’s leading professional ser...
# 4   HDFC Bank  is one of India’s leading private banks and wa...

# %%
subset = df_cleaned

# Convert to list of dicts
records = [
    {"input": row["clean_about"], "output": row["name"]}
    for _, row in subset.iterrows()
]

# Save to JSON
with open("companies_clean.json", "w") as f:
    json.dump(records, f, indent=4)

print("✅ Saved cleaned dataset to companies_clean.json")
# Out:
# ✅ Saved cleaned dataset to companies_clean.json

# %%
# lets start our tunning
file = json.load(open("companies_clean.json", "r"))
print(file[1])
# Out:
# {'input': 'is a leading global professional services company, providing a broad range of services and solutions in strategy, consulting, digital, technology and operations. Combining unmatched experience and specialized skills across more than 40 industries and all business functions – underpinned by the world’s largest delivery network – works at the intersection of business and technology to help clients improve their performance and create sustainable value for their stakeholders. With 449,000 people serving clients in more than 120 countries, drives innovation to improve the way the world works and lives. Visit us at', 'output': 'Accenture'}

# %%
# Checking the GPU
import torch
print(f"CUDA available : {torch.cuda.is_available()}")
print(f"GPU = {torch.cuda.get_device_name(0) if torch.cuda.is_available() else None}")
# Out:
# CUDA available : True
# GPU = Tesla T4

# %%
from unsloth import FastLanguageModel
import torch

model_name = "unsloth/Phi-3-mini-4k-instruct-bnb-4bit"

max_seq_leght = 2048
dtype = None

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_leght,
    dtype = dtype,
    load_in_4bit = True,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.10: Fast Mistral patching. Transformers: 4.55.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/194 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/458 [00:00<?, ?B/s]
# ...

# %%
from datasets import Dataset

def format_prompt(example):
    return (
        f"### Input: Business Description: {example['input']}\n"
        f"### Output: {json.dumps({'company_name': example['output']})}<|endoftext|>"
    )

# Load your file
with open("companies_clean.json", "r") as f:
    file = json.load(f)


formatted_data = [format_prompt(item) for item in file]
dataset = Dataset.from_dict({"text": formatted_data})

print(dataset[0]["text"])  # show first prompt
# Out:
# ### Input: Business Description: Tata Consultancy Services is an IT services, consulting and business solutions organisation that has been partnering with the world’s largest businesses in their transformation journeys for the last 50 years. A part of the Tata group, India's largest multinational business group, has over 436,000 of the world’s best-trained consultants in 46 countries. The company is listed on the the India. '​ proactive stance on climate change and award winning work with communities across the world have earned it a place in leading sustainability indices such as the Dow Jones Sustainability Index , MSCI Global Sustainability Index and the FTSE4Good Emerging Index
# ### Output: {"company_name": "TCS"}<|endoftext|>

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = 32,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2025.8.10 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments


trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,  # Lowered
    dataset_num_proc=2,
    args=TrainingArguments(
        per_device_train_batch_size=1,   # Lowered
        gradient_accumulation_steps=4,
        warmup_steps=10,
        num_train_epochs=3,
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=25,
        optim="adamw_torch",             # Safer optimizer
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        save_strategy="epoch",
        save_total_limit=2,
        dataloader_pin_memory=False,
        report_to="none",
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/15570 [00:00<?, ? examples/s]

# %%
# Train the model
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 15,570 | Num Epochs = 3 | Total steps = 11,679
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 29,884,416 of 3,850,963,968 (0.78% trained)
#     <div>
#
#       <progress value='1006' max='11679' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1006/11679 41:31 < 7:21:21, 0.40 it/s, Epoch 0.26/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>2.326300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.154400</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.120400</td>
#     </tr>
#     <tr>
# ...

# %%
from unsloth import FastLanguageModel
import torch

# Enable 2x faster inference
FastLanguageModel.for_inference(model)

while True:
    # User provides business description
    user_desc = input("Enter a company description (or 'quit' to stop): ")
    if user_desc.lower() == "quit":
        break

    # Build messages (chat template style)
    messages = [
        {"role": "user", "content": f"### Input: Business Description: {user_desc}\n### Output:"}
    ]

    # Tokenize
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt",
    ).to("cuda")

    # Generate
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=128,
        use_cache=True,
        temperature=0.7,
        do_sample=True,
        top_p=0.9,
    )

    # Decode
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Print only the assistant's part (after "### Output:")
    if "### Output:" in response:
        response = response.split("### Output:")[-1].strip()

    print(f"\nPredicted company name: {response}\n")
